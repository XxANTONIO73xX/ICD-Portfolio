# %% [markdown]
# <html>
#     <style>
#         h1{ font-size: 40px; margin: auto

# %% [markdown]
# <html>
#     <style>
#         h1, p{
#             text-align: center;
#         }
#         .container{ width: 100%; padding: 0; margin: 0;}
#         img{
#             width: 100%;
#             margin: 0;
#             padding: 0;
#         }
#     </style>
#     <div class="container">
#         <h1>Analisis Exploratorio</h1>
#         <p>Sign Language MNIST</p>
#     </div>
#     <div class="container">
#         <img src="img/dataset-cover.png">
#     </div>
#
# </html>

# %% [markdown]
# <html>
#     <style>
#         h1{
#             text-align: center;
#         }
#         p{
#             text-align: justify;
#         }
#         .container{ width: 99

# %% [markdown]
# <html>
#     <style>
#         h1{
#             text-align: center;
#         }
#         p{
#             text-align: justify;
#         }
#         .container{ width: 97%; padding: 0; margin: 0 1%;}
#     </style>
#     <div class="container">
#         <h1>Acerca del conjunto de datos</h1>
#         <p>Los investigadores han estado trabajando en actualizar y crear sustitutos desafiantes para el conjunto de datos MNIST de dígitos manuscritos, que es ampliamente utilizado en el aprendizaje automático basado en imágenes. Un ejemplo reciente de esto es el conjunto de datos Fashion-MNIST. Los investigadores de Zalando señalaron que incluso un solo píxel puede distinguir la mayoría de los pares de dígitos MNIST, lo que motivó la creación de nuevos conjuntos de datos como MNIST de lenguaje de señas. Este nuevo conjunto de datos representa el lenguaje de señas americano de gestos con las manos y presenta un desafío multiclase con 24 clases de letras, excluyendo la J y la Z que requieren movimiento. El objetivo es estimular a la comunidad de investigadores a desarrollar más alternativas originales y desafiantes para aplicaciones del mundo real en visión por ordenador.</p>
#         <a src="https://chat.openai.com/">Sintesis by ChatGPT</a> --- <a src="https://www.kaggle.com/datasets/datamunge/sign-language-mnist">Kaggle dataset</a>
#     </div>
# </html>

# %% [markdown]
# Librerias Utilizadas:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importar el conjunto de Datos

# %%
df_test = pd.read_csv(r"../dataset/sign_mnist_test/sign_mnist_test.csv")
df_train = pd.read_csv(r"../dataset/sign_mnist_train/sign_mnist_train.csv")

# %% [markdown]
# DataFrame *df_test*

# %%
df_test
# Out:
#       label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0         6     149     149     150     150     150     151     151     150
# 1         5     126     128     131     132     133     134     135     135
# 2        10      85      88      92      96     105     123     135     143
# 3         0     203     205     207     206     207     209     210     209
# 4         3     188     191     193     195     199     201     202     203
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 7167      1     135     119     108     102     105      99      61     103
# 7168     12     157     159     161     164     166     166     171     174
# 7169      2     190     191     190     191     190     190     192     192
# 7170      4     201     205     208     209     214     216     218     223
# 7171      2     173     174     173     174     173     173     175     175
#
# ...

# %% [markdown]
# DataFrame *df_tain*

# %%
df_train
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27450     13     189     189     190     190     192     193     193     193
# 27451     23     151     154     157     158     160     161     163     164
# 27452     18     174     174     174     174     174     175     175     174
# 27453     17     177     181     184     185     187     189     190     191
# 27454     23     179     180     180     180     182     181     182     183
#
# ...

# %%
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean      12.318813    145.419377    148.500273    151.247714    153.546531
# std        7.287552     41.358555     39.942152     39.056286     38.595247
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000    121.000000    126.000000    130.000000    133.000000
# 50%       13.000000    150.000000    153.000000    156.000000    158.000000
# 75%       19.000000    174.000000    176.000000    178.000000    179.000000
# max       24.000000    255.000000    255.000000    255.000000    255.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean     156.210891    158.411255    160.472154    162.339683    163.954799
# ...

# %%
# Out:
# array([[<Axes: title={'center': 'label'}>,
#         <Axes: title={'center': 'pixel1'}>,
#         <Axes: title={'center': 'pixel2'}>,
#         <Axes: title={'center': 'pixel3'}>,
#         <Axes: title={'center': 'pixel4'}>,
#         <Axes: title={'center': 'pixel5'}>,
#         <Axes: title={'center': 'pixel6'}>,
#         <Axes: title={'center': 'pixel7'}>,
#         <Axes: title={'center': 'pixel8'}>,
#         <Axes: title={'center': 'pixel9'}>,
#         <Axes: title={'center': 'pixel10'}>,
#         <Axes: title={'center': 'pixel11'}>,
#         <Axes: title={'center': 'pixel12'}>,
#         <Axes: title={'center': 'pixel13'}>,
#         <Axes: title={'center': 'pixel14'}>,
#         <Axes: title={'center': 'pixel15'}>,
#         <Axes: title={'center': 'pixel16'}>,
#         <Axes: title={'center': 'pixel17'}>,
#         <Axes: title={'center': 'pixel18'}>,
#         <Axes: title={'center': 'pixel19'}>,
#         <Axes: title={'center': 'pixel20'}>,
# ...
